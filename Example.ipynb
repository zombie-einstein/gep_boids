# %%
import boid
from IPython.display import HTML

# %%
F = boid.Flock(10.0, 10.0, 50, 0.25, 0.1, 0.1, 1)

# %%
F.boid_steps.visualize()

# %%
HTML(F.run_and_animate(100).to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
